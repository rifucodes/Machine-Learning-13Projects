# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\jabeen\Downloads\Arif\Dataset/historical_weather_data.csv')
df.head()
# Out:
#          Date   Station  Temperature  Precipitation   Humidity  WindSpeed  \
# 0  2020-01-01  Station1     6.653288        0.00000  64.421750   9.562955
# 1  2020-01-02  Station1    -2.031372        2.98847  85.492843   6.502074
# 2  2020-01-03  Station1    -6.428333        0.00000  90.456869   3.486873
# 3  2020-01-04  Station1    31.471383        0.00000  98.352442  17.288559
# 4  2020-01-05  Station1    34.220877        0.00000  89.589972  12.807424
#
#   WeatherCondition
# 0    Partly Cloudy
# 1           Cloudy
# 2             Snow
# 3    Partly Cloudy
# 4             Snow

# %%
df.shape
# Out:
# (1095, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1095 non-null   object
#  1   Station           1095 non-null   object
#  2   Temperature       1095 non-null   float64
#  3   Precipitation     1095 non-null   float64
#  4   Humidity          1095 non-null   float64
#  5   WindSpeed         1095 non-null   float64
#  6   WeatherCondition  1095 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 60.0+ KB

# %%
df.isna().sum()
# Out:
# Date                0
# Station             0
# Temperature         0
# Precipitation       0
# Humidity            0
# WindSpeed           0
# WeatherCondition    0
# dtype: int64

# %%
from sklearn import preprocessing
label=preprocessing.LabelEncoder()
df['Date']=label.fit_transform(df['Date'])
df['Station']=label.fit_transform(df['Station'])
#df['WeatherCondition']=label.fit_transform(df['WeatherCondition'])

# %%
df.head()
# Out:
#    Date  Station  Temperature  Precipitation   Humidity  WindSpeed  \
# 0     0        0     6.653288        0.00000  64.421750   9.562955
# 1     1        0    -2.031372        2.98847  85.492843   6.502074
# 2     2        0    -6.428333        0.00000  90.456869   3.486873
# 3     3        0    31.471383        0.00000  98.352442  17.288559
# 4     4        0    34.220877        0.00000  89.589972  12.807424
#
#   WeatherCondition
# 0    Partly Cloudy
# 1           Cloudy
# 2             Snow
# 3    Partly Cloudy
# 4             Snow

# %%
x= df.drop('WeatherCondition',axis=1)
y=df['WeatherCondition']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.9,random_state=41)

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm_pred=svm.predict(x_test)
svm_pred
# Out:
# array(['Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Partly Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Partly Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Cloudy', 'Partly Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Partly Cloudy',
#        'Partly Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Partly Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Cloudy', 'Partly Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Partly Cloudy', 'Cloudy',
#        'Partly Cloudy', 'Cloudy', 'Partly Cloudy', 'Partly Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Partly Cloudy', 'Cloudy', 'Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Partly Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Partly Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy'], dtype=object)

# %%
svm.score(x_test,y_test)
# Out:
# 0.13636363636363635

# %%
kernel1=SVC(kernel='linear')
kernel1.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
kernel1.score(x_test,y_test)
# Out:
# 0.19090909090909092

# %%
kernel2=SVC(kernel='poly')
kernel2.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
kernel2.score(x_test,y_test)
# Out:
# 0.20909090909090908

# %%
kernel3=SVC(kernel='rbf')
kernel3.fit(x_train,y_train)
# Out:
# SVC()

# %%
kernel3.score(x_test,y_test)
# Out:
# 0.22727272727272727

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression()
logistic.fit(x_train,y_train)
# Out:
# /home/ubundu/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic.predict(x_test)
# Out:
# array(['Rain', 'Rain', 'Cloudy', 'Partly Cloudy', 'Rain', 'Partly Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Partly Cloudy', 'Rain',
#        'Partly Cloudy', 'Rain', 'Partly Cloudy', 'Rain', 'Cloudy', 'Rain',
#        'Snow', 'Snow', 'Snow', 'Rain', 'Snow', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Cloudy', 'Cloudy', 'Snow', 'Snow',
#        'Cloudy', 'Snow', 'Cloudy', 'Rain', 'Cloudy', 'Rain', 'Cloudy',
#        'Rain', 'Cloudy', 'Partly Cloudy', 'Snow', 'Rain', 'Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Snow', 'Cloudy', 'Cloudy', 'Sunny', 'Rain', 'Snow',
#        'Cloudy', 'Snow', 'Cloudy', 'Partly Cloudy', 'Sunny', 'Cloudy',
#        'Snow', 'Cloudy', 'Partly Cloudy', 'Cloudy', 'Partly Cloudy',
#        'Rain', 'Rain', 'Rain', 'Sunny', 'Rain', 'Partly Cloudy', 'Cloudy',
#        'Sunny', 'Partly Cloudy', 'Partly Cloudy', 'Rain', 'Partly Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Cloudy', 'Rain', 'Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Sunny', 'Cloudy', 'Snow',
#        'Partly Cloudy', 'Partly Cloudy', 'Cloudy', 'Partly Cloudy',
#        'Snow', 'Rain', 'Sunny', 'Rain', 'Snow', 'Cloudy', 'Rain', 'Rain',
#        'Snow', 'Cloudy', 'Partly Cloudy', 'Cloudy', 'Sunny', 'Sunny',
#        'Rain', 'Cloudy', 'Snow', 'Cloudy'], dtype=object)

# %%
logistic.score(x_test,y_test)
# Out:
# 0.15454545454545454

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
knn.score(x_test,y_test)
# Out:
# 0.23636363636363636

# %%
accuracy_rate=[]
for i in range(1,40):


    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    score=knn.score(x_test,y_test)
    accuracy_rate.append(score)

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),accuracy_rate,color='red',linestyle='dashed',marker='o',
        markerfacecolor='blue',markersize=10)
plt.title('accuracy_rate vs. K Value')
plt.xlabel('k_value')
plt.ylabel('accuracy_rate')
# Out:
# Text(0, 0.5, 'accuracy_rate')

# %%
error_rate=[]
for i in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    pred_i=knn.predict(x_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='green',marker='o',linestyle='dashed',
        markerfacecolor='red',markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K_value')
plt.ylabel('Error rate')
# Out:
# Text(0, 0.5, 'Error rate')

# %%
knn1=KNeighborsClassifier(n_neighbors=6)
knn1.fit(x_train,y_train)
knn1.score(x_test,y_test)
# Out:
# 0.24545454545454545

# %%
knn2=KNeighborsClassifier(n_neighbors=7)
knn2.fit(x_train,y_train)
knn2.score(x_test,y_test)
# Out:
# 0.2545454545454545

# %%
knn3=KNeighborsClassifier(n_neighbors=8)
knn3.fit(x_train,y_train)
knn3.score(x_test,y_test)
# Out:
# 0.2818181818181818

# %%
knn_predict=knn1.predict(x_test)

# %%
plt.plot(knn_predict,color='blue',linestyle='-',marker='o')
plt.title('Customer Excitment')  
plt.xlabel('Data points')  
plt.ylabel('Data values')
# Out:
# Text(0, 0.5, 'Data values')

# %%
from sklearn.naive_bayes import GaussianNB
naive=GaussianNB()
naive.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
naive.predict(x_test)
# Out:
# array(['Snow', 'Rain', 'Cloudy', 'Partly Cloudy', 'Partly Cloudy',
#        'Partly Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Sunny',
#        'Partly Cloudy', 'Partly Cloudy', 'Partly Cloudy', 'Snow', 'Sunny',
#        'Sunny', 'Rain', 'Snow', 'Snow', 'Snow', 'Sunny', 'Snow', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Sunny', 'Cloudy', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Sunny', 'Cloudy', 'Sunny',
#        'Partly Cloudy', 'Rain', 'Cloudy', 'Partly Cloudy', 'Snow',
#        'Partly Cloudy', 'Rain', 'Partly Cloudy', 'Partly Cloudy',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Cloudy', 'Rain', 'Cloudy',
#        'Sunny', 'Partly Cloudy', 'Partly Cloudy', 'Snow', 'Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Sunny', 'Cloudy', 'Cloudy',
#        'Partly Cloudy', 'Rain', 'Cloudy', 'Cloudy', 'Sunny', 'Snow',
#        'Rain', 'Sunny', 'Rain', 'Partly Cloudy', 'Partly Cloudy', 'Sunny',
#        'Rain', 'Sunny', 'Rain', 'Partly Cloudy', 'Sunny', 'Partly Cloudy',
#        'Snow', 'Rain', 'Cloudy', 'Partly Cloudy', 'Partly Cloudy',
#        'Cloudy', 'Cloudy', 'Snow', 'Partly Cloudy', 'Partly Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Cloudy', 'Cloudy', 'Sunny',
#        'Partly Cloudy', 'Rain', 'Snow', 'Partly Cloudy', 'Rain', 'Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Rain', 'Rain', 'Sunny', 'Rain',
#        'Cloudy', 'Snow', 'Cloudy'], dtype='<U13')

# %%
naive.score(x_test,y_test)
# Out:
# 0.2

# %%
from sklearn.ensemble import RandomForestClassifier
random=RandomForestClassifier()
random.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
random_predict=random.predict(x_test)
random_predict
# Out:
# array(['Snow', 'Sunny', 'Cloudy', 'Partly Cloudy', 'Rain', 'Cloudy',
#        'Sunny', 'Cloudy', 'Snow', 'Partly Cloudy', 'Partly Cloudy',
#        'Snow', 'Rain', 'Cloudy', 'Sunny', 'Cloudy', 'Partly Cloudy',
#        'Snow', 'Cloudy', 'Snow', 'Sunny', 'Rain', 'Cloudy', 'Cloudy',
#        'Cloudy', 'Rain', 'Rain', 'Rain', 'Partly Cloudy', 'Cloudy',
#        'Rain', 'Sunny', 'Cloudy', 'Sunny', 'Sunny', 'Sunny', 'Cloudy',
#        'Sunny', 'Partly Cloudy', 'Sunny', 'Sunny', 'Rain', 'Rain',
#        'Partly Cloudy', 'Snow', 'Cloudy', 'Cloudy', 'Snow', 'Snow',
#        'Partly Cloudy', 'Partly Cloudy', 'Rain', 'Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Snow', 'Snow', 'Rain', 'Snow',
#        'Partly Cloudy', 'Cloudy', 'Rain', 'Cloudy', 'Partly Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Cloudy', 'Rain', 'Snow', 'Sunny',
#        'Sunny', 'Rain', 'Partly Cloudy', 'Rain', 'Partly Cloudy', 'Sunny',
#        'Sunny', 'Partly Cloudy', 'Rain', 'Cloudy', 'Snow', 'Rain',
#        'Sunny', 'Rain', 'Snow', 'Sunny', 'Cloudy', 'Snow', 'Rain', 'Snow',
#        'Cloudy', 'Rain', 'Partly Cloudy', 'Rain', 'Partly Cloudy',
#        'Cloudy', 'Rain', 'Sunny', 'Partly Cloudy', 'Sunny', 'Rain',
#        'Rain', 'Cloudy', 'Rain', 'Rain', 'Sunny', 'Rain', 'Rain',
#        'Cloudy', 'Snow'], dtype=object)

# %%
random.score(x_test,y_test)
# Out:
# 0.23636363636363636

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,classification_report

# %%
cm = confusion_matrix(y_test, random_predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
cr= classification_report(y_test, random_predict)
plt.plot(cr)
plt.title("classification_report")
plt.xlabel('customer info')
plt.ylabel('excitment')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.predict(x_test)
# Out:
# array(['Snow', 'Partly Cloudy', 'Cloudy', 'Cloudy', 'Snow', 'Cloudy',
#        'Partly Cloudy', 'Cloudy', 'Snow', 'Sunny', 'Partly Cloudy',
#        'Rain', 'Rain', 'Cloudy', 'Cloudy', 'Sunny', 'Partly Cloudy',
#        'Rain', 'Cloudy', 'Sunny', 'Sunny', 'Snow', 'Snow',
#        'Partly Cloudy', 'Cloudy', 'Sunny', 'Snow', 'Sunny', 'Snow',
#        'Cloudy', 'Cloudy', 'Cloudy', 'Rain', 'Sunny', 'Rain', 'Sunny',
#        'Cloudy', 'Rain', 'Cloudy', 'Sunny', 'Sunny', 'Sunny', 'Rain',
#        'Cloudy', 'Partly Cloudy', 'Partly Cloudy', 'Snow', 'Rain',
#        'Partly Cloudy', 'Rain', 'Partly Cloudy', 'Rain', 'Cloudy',
#        'Sunny', 'Rain', 'Snow', 'Snow', 'Snow', 'Sunny', 'Partly Cloudy',
#        'Cloudy', 'Rain', 'Rain', 'Partly Cloudy', 'Snow', 'Snow',
#        'Cloudy', 'Rain', 'Snow', 'Sunny', 'Cloudy', 'Snow', 'Cloudy',
#        'Partly Cloudy', 'Partly Cloudy', 'Partly Cloudy', 'Cloudy',
#        'Snow', 'Cloudy', 'Snow', 'Snow', 'Rain', 'Sunny', 'Sunny',
#        'Partly Cloudy', 'Partly Cloudy', 'Snow', 'Snow', 'Partly Cloudy',
#        'Snow', 'Snow', 'Rain', 'Rain', 'Snow', 'Partly Cloudy', 'Cloudy',
#        'Cloudy', 'Partly Cloudy', 'Sunny', 'Sunny', 'Snow', 'Sunny',
#        'Snow', 'Sunny', 'Cloudy', 'Snow', 'Rain', 'Rain', 'Cloudy',
#        'Rain'], dtype=object)

# %%
tree.score(x_test,y_test)
# Out:
# 0.20909090909090908

# %%
import xgboost as xgb
boost = xgb.XGBClassifier()
boost.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 import xgboost as xgb
#       2 boost = xgb.XGBClassifier()
# ----> 3 boost.fit(x_train, y_train)
#
# File ~/.local/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/xgboost/sklearn.py:1640, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1635     expected_classes = self.classes_
#    1636 if (
#    1637     classes.shape != expected_classes.shape
#    1638     or not (classes == expected_classes).all()
#    1639 ):
# -> 1640     raise ValueError(
#    1641         f"Invalid classes inferred from unique values of `y`.  "
#    1642         f"Expected: {expected_classes}, got {classes}"
#    1643     )
#    1645 params = self.get_xgb_params()
#    1647 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1 2 3 4], got ['Cloudy' 'Partly Cloudy' 'Rain' 'Snow' 'Sunny']

# %%
boost.predict(x_test)

# %%
boost.score(x_test,y_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
rf_model = RandomForestClassifier()

param_grid = {
    'n_estimators': [1, 5, 10]
}

gdc = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, return_train_score=True)

# %%
gdc

# %%
gdc.fit(x,y)

# %%
gdc.best_params_

# %%
from sklearn import svm

model_params = {
    'svm': {
        'model': svm.SVC(),
        'params': {
            'gamma': [1, 10, 20],
            'C': [1, 10, 20],
            'kernel': ['rbf', 'poly', 'linear']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params': {
            'n_estimators': [1, 5, 10]
        }
    }
}

# %%
scores=[]
for model_name in model_params:
    mp=model_params[model_name]
    gds=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=True)
    gds.fit(x,y)
    scores.append({'model':model_name,'best_score':gds.best_score_,'best_params':gds.best_params_})

# %%
scores

# %%
models={'logistic':{'model':LogisticRegression(),'params':{}},
        'random_forest':{'model':RandomForestClassifier(),'params':{'n_estimators':[1,10,20,100]}},
        'decision_tree':{'model':DecisionTreeClassifier(),'params':{}},
        'Gaussian':{'model':GaussianNB(),'params':{}},
        'Bernauli':{'model':BernoulliNB(),'params':{}},
        'SVM':{'model':SVC(),'params':{'gamma':[1,2,100],'C':[1,2,5,100],'kernel':['poly','linear','sigmoid','rbf']}}}

result=[]
for i in models:
    a=models.get(i)
    model=a.get('model')
    params=a.get('params')
    cv=GridSearchCV(model,params,cv=5,return_train_score=True)
    cv.fit(x,y)
    bp=cv.best_params_
    bs=cv.best_score_
    t_res={'model':i,'best_params':bp,'best_score':bs}
    result.append(t_res)
f=pd.DataFrame(result)
